# %%
# !pip install viphoneme
# !pip install vietnam-number
# !pip install eng_to_ipa
# !pip install underthesea
# !pip install prosodic
# !pip install vinorm
# Out:
# Requirement already satisfied: viphoneme in c:\users\admin\desktop\vit-vn\vits-vn\venv\lib\site-packages (2.0.1)
# Requirement already satisfied: vietnam-number in c:\users\admin\desktop\vit-vn\vits-vn\venv\lib\site-packages (1.0.3)
# Requirement already satisfied: eng_to_ipa in c:\users\admin\desktop\vit-vn\vits-vn\venv\lib\site-packages (0.0.2)
# Requirement already satisfied: underthesea in c:\users\admin\desktop\vit-vn\vits-vn\venv\lib\site-packages (6.7.0)
# Requirement already satisfied: Click>=6.0 in c:\users\admin\desktop\vit-vn\vits-vn\venv\lib\site-packages (from underthesea) (8.1.6)
# Requirement already satisfied: python-crfsuite>=0.9.6 in c:\users\admin\desktop\vit-vn\vits-vn\venv\lib\site-packages (from underthesea) (0.9.9)
# Requirement already satisfied: nltk in c:\users\admin\desktop\vit-vn\vits-vn\venv\lib\site-packages (from underthesea) (3.8.1)
# Requirement already satisfied: tqdm in c:\users\admin\desktop\vit-vn\vits-vn\venv\lib\site-packages (from underthesea) (4.65.0)
# Requirement already satisfied: requests in c:\users\admin\desktop\vit-vn\vits-vn\venv\lib\site-packages (from underthesea) (2.31.0)
# Requirement already satisfied: joblib in c:\users\admin\desktop\vit-vn\vits-vn\venv\lib\site-packages (from underthesea) (1.3.1)
# Requirement already satisfied: scikit-learn in c:\users\admin\desktop\vit-vn\vits-vn\venv\lib\site-packages (from underthesea) (1.3.0)
# Requirement already satisfied: PyYAML in c:\users\admin\desktop\vit-vn\vits-vn\venv\lib\site-packages (from underthesea) (6.0.1)
# Requirement already satisfied: underthesea-core==1.0.4 in c:\users\admin\desktop\vit-vn\vits-vn\venv\lib\site-packages (from underthesea) (1.0.4)
# Requirement already satisfied: colorama in c:\users\admin\desktop\vit-vn\vits-vn\venv\lib\site-packages (from Click>=6.0->underthesea) (0.4.6)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\admin\desktop\vit-vn\vits-vn\venv\lib\site-packages (from nltk->underthesea) (2023.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\desktop\vit-vn\vits-vn\venv\lib\site-packages (from requests->underthesea) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\desktop\vit-vn\vits-vn\venv\lib\site-packages (from requests->underthesea) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\desktop\vit-vn\vits-vn\venv\lib\site-packages (from requests->underthesea) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\desktop\vit-vn\vits-vn\venv\lib\site-packages (from requests->underthesea) (2023.7.22)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\admin\desktop\vit-vn\vits-vn\venv\lib\site-packages (from scikit-learn->underthesea) (1.24.4)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\admin\desktop\vit-vn\vits-vn\venv\lib\site-packages (from scikit-learn->underthesea) (1.11.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\desktop\vit-vn\vits-vn\venv\lib\site-packages (from scikit-learn->underthesea) (3.2.0)

# %%
# !wget -nc https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# !conda install --channel defaults conda python=3.8 --yes
# !conda update --channel defaults --all --yes
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# 'chmod' is not recognized as an internal or external command,
# operable program or batch file.
# '.' is not recognized as an internal or external command,
# operable program or batch file.
# 'conda' is not recognized as an internal or external command,
# operable program or batch file.
# 'conda' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# %matplotlib inline
# import matplotlib.pyplot as plt
import IPython.display as ipd

import os
import json
import math
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader

import commons
import utils
from data_utils import TextAudioLoader, TextAudioCollate, TextAudioSpeakerLoader, TextAudioSpeakerCollate
from models import SynthesizerTrn
from text.symbols import symbols
from text import text_to_sequence

from scipy.io.wavfile import write


def get_text(text, hps):
    text_norm = text_to_sequence(text, hps.data.text_cleaners)
    if hps.data.add_blank:
        text_norm = commons.intersperse(text_norm, 0)
    text_norm = torch.LongTensor(text_norm)
    return text_norm
# Out:
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=1051)
#            2	RESUME(arg=0, lineno=1051)
#            4	LOAD_FAST(arg=0, lineno=1054)
#            6	LOAD_CONST(arg=1, lineno=1054)
#            8	BINARY_SUBSCR(arg=None, lineno=1054)
#           18	LOAD_FAST(arg=0, lineno=1054)
#           20	LOAD_CONST(arg=2, lineno=1054)
#           22	BINARY_SUBSCR(arg=None, lineno=1054)
#           32	COMPARE_OP(arg=4, lineno=1054)
#           38	LOAD_FAST(arg=0, lineno=1054)
#           40	LOAD_CONST(arg=1, lineno=1054)
#           42	BINARY_SUBSCR(arg=None, lineno=1054)
#           52	LOAD_FAST(arg=0, lineno=1054)
#           54	LOAD_CONST(arg=3, lineno=1054)
#           56	BINARY_SUBSCR(arg=None, lineno=1054)
#           66	COMPARE_OP(arg=5, lineno=1054)
#           72	BINARY_OP(arg=1, lineno=1054)
#           76	RETURN_VALUE(arg=None, lineno=1054)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=0 nstack_initial=0)
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=1051)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=RESUME(arg=0, lineno=1051)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_FAST(arg=0, lineno=1054)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=LOAD_CONST(arg=1, lineno=1054)
# DEBUG:numba.core.byteflow:stack ['$x4.0']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=BINARY_SUBSCR(arg=None, lineno=1054)
# DEBUG:numba.core.byteflow:stack ['$x4.0', '$const6.1']
# DEBUG:numba.core.byteflow:dispatch pc=18, inst=LOAD_FAST(arg=0, lineno=1054)
# DEBUG:numba.core.byteflow:stack ['$8binary_subscr.2']
# DEBUG:numba.core.byteflow:dispatch pc=20, inst=LOAD_CONST(arg=2, lineno=1054)
# DEBUG:numba.core.byteflow:stack ['$8binary_subscr.2', '$x18.3']
# DEBUG:numba.core.byteflow:dispatch pc=22, inst=BINARY_SUBSCR(arg=None, lineno=1054)
# DEBUG:numba.core.byteflow:stack ['$8binary_subscr.2', '$x18.3', '$const20.4']
# DEBUG:numba.core.byteflow:dispatch pc=32, inst=COMPARE_OP(arg=4, lineno=1054)
# DEBUG:numba.core.byteflow:stack ['$8binary_subscr.2', '$22binary_subscr.5']
# DEBUG:numba.core.byteflow:dispatch pc=38, inst=LOAD_FAST(arg=0, lineno=1054)
# DEBUG:numba.core.byteflow:stack ['$32compare_op.6']
# DEBUG:numba.core.byteflow:dispatch pc=40, inst=LOAD_CONST(arg=1, lineno=1054)
# DEBUG:numba.core.byteflow:stack ['$32compare_op.6', '$x38.7']
# DEBUG:numba.core.byteflow:dispatch pc=42, inst=BINARY_SUBSCR(arg=None, lineno=1054)
# DEBUG:numba.core.byteflow:stack ['$32compare_op.6', '$x38.7', '$const40.8']
# DEBUG:numba.core.byteflow:dispatch pc=52, inst=LOAD_FAST(arg=0, lineno=1054)
# DEBUG:numba.core.byteflow:stack ['$32compare_op.6', '$42binary_subscr.9']
# DEBUG:numba.core.byteflow:dispatch pc=54, inst=LOAD_CONST(arg=3, lineno=1054)
# DEBUG:numba.core.byteflow:stack ['$32compare_op.6', '$42binary_subscr.9', '$x52.10']
# DEBUG:numba.core.byteflow:dispatch pc=56, inst=BINARY_SUBSCR(arg=None, lineno=1054)
# DEBUG:numba.core.byteflow:stack ['$32compare_op.6', '$42binary_subscr.9', '$x52.10', '$const54.11']
# DEBUG:numba.core.byteflow:dispatch pc=66, inst=COMPARE_OP(arg=5, lineno=1054)
# DEBUG:numba.core.byteflow:stack ['$32compare_op.6', '$42binary_subscr.9', '$56binary_subscr.12']
# DEBUG:numba.core.byteflow:dispatch pc=72, inst=BINARY_OP(arg=1, lineno=1054)
# DEBUG:numba.core.byteflow:stack ['$32compare_op.6', '$66compare_op.13']
# DEBUG:numba.core.byteflow:dispatch pc=76, inst=RETURN_VALUE(arg=None, lineno=1054)
# DEBUG:numba.core.byteflow:stack ['$binop_and_72.14']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {}), (4, {'res': '$x4.0'}), (6, {'res': '$const6.1'}), (8, {'index': '$const6.1', 'target': '$x4.0', 'res': '$8binary_subscr.2'}), (10, {}), (12, {}), (14, {}), (16, {}), (18, {'res': '$x18.3'}), (20, {'res': '$const20.4'}), (22, {'index': '$const20.4', 'target': '$x18.3', 'res': '$22binary_subscr.5'}), (24, {}), (26, {}), (28, {}), (30, {}), (32, {'lhs': '$8binary_subscr.2', 'rhs': '$22binary_subscr.5', 'res': '$32compare_op.6'}), (34, {}), (36, {}), (38, {'res': '$x38.7'}), (40, {'res': '$const40.8'}), (42, {'index': '$const40.8', 'target': '$x38.7', 'res': '$42binary_subscr.9'}), (44, {}), (46, {}), (48, {}), (50, {}), (52, {'res': '$x52.10'}), (54, {'res': '$const54.11'}), (56, {'index': '$const54.11', 'target': '$x52.10', 'res': '$56binary_subscr.12'}), (58, {}), (60, {}), (62, {}), (64, {}), (66, {'lhs': '$42binary_subscr.9', 'rhs': '$56binary_subscr.12', 'res': '$66compare_op.13'}), (68, {}), (70, {}), (72, {'op': '&', 'lhs': '$32compare_op.6', 'rhs': '$66compare_op.13', 'res': '$binop_and_72.14'}), (74, {}), (76, {'retval': '$binop_and_72.14', 'castval': '$76return_value.15'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     x = arg(0, name=x)                       ['x']
#     $const6.1 = const(int, 0)                ['$const6.1']
#     $8binary_subscr.2 = getitem(value=x, index=$const6.1, fn=<built-in function getitem>) ['$8binary_subscr.2', '$const6.1', 'x']
#     $const20.4 = const(int, -1)              ['$const20.4']
#     $22binary_subscr.5 = getitem(value=x, index=$const20.4, fn=<built-in function getitem>) ['$22binary_subscr.5', '$const20.4', 'x']
#     $32compare_op.6 = $8binary_subscr.2 > $22binary_subscr.5 ['$22binary_subscr.5', '$32compare_op.6', '$8binary_subscr.2']
#     $const40.8 = const(int, 0)               ['$const40.8']
#     $42binary_subscr.9 = getitem(value=x, index=$const40.8, fn=<built-in function getitem>) ['$42binary_subscr.9', '$const40.8', 'x']
#     $const54.11 = const(int, 1)              ['$const54.11']
#     $56binary_subscr.12 = getitem(value=x, index=$const54.11, fn=<built-in function getitem>) ['$56binary_subscr.12', '$const54.11', 'x']
#     $66compare_op.13 = $42binary_subscr.9 >= $56binary_subscr.12 ['$42binary_subscr.9', '$56binary_subscr.12', '$66compare_op.13']
#     $binop_and_72.14 = $32compare_op.6 & $66compare_op.13 ['$32compare_op.6', '$66compare_op.13', '$binop_and_72.14']
#     $76return_value.15 = cast(value=$binop_and_72.14) ['$76return_value.15', '$binop_and_72.14']
#     return $76return_value.15                ['$76return_value.15']
#
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=1057)
#            2	RESUME(arg=0, lineno=1057)
#            4	LOAD_FAST(arg=0, lineno=1060)
#            6	LOAD_CONST(arg=1, lineno=1060)
#            8	BINARY_SUBSCR(arg=None, lineno=1060)
#           18	LOAD_FAST(arg=0, lineno=1060)
#           20	LOAD_CONST(arg=2, lineno=1060)
#           22	BINARY_SUBSCR(arg=None, lineno=1060)
#           32	COMPARE_OP(arg=0, lineno=1060)
#           38	LOAD_FAST(arg=0, lineno=1060)
#           40	LOAD_CONST(arg=1, lineno=1060)
#           42	BINARY_SUBSCR(arg=None, lineno=1060)
#           52	LOAD_FAST(arg=0, lineno=1060)
#           54	LOAD_CONST(arg=3, lineno=1060)
#           56	BINARY_SUBSCR(arg=None, lineno=1060)
#           66	COMPARE_OP(arg=1, lineno=1060)
#           72	BINARY_OP(arg=1, lineno=1060)
#           76	RETURN_VALUE(arg=None, lineno=1060)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=0 nstack_initial=0)
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=1057)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=RESUME(arg=0, lineno=1057)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_FAST(arg=0, lineno=1060)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=LOAD_CONST(arg=1, lineno=1060)
# DEBUG:numba.core.byteflow:stack ['$x4.0']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=BINARY_SUBSCR(arg=None, lineno=1060)
# DEBUG:numba.core.byteflow:stack ['$x4.0', '$const6.1']
# DEBUG:numba.core.byteflow:dispatch pc=18, inst=LOAD_FAST(arg=0, lineno=1060)
# DEBUG:numba.core.byteflow:stack ['$8binary_subscr.2']
# DEBUG:numba.core.byteflow:dispatch pc=20, inst=LOAD_CONST(arg=2, lineno=1060)
# DEBUG:numba.core.byteflow:stack ['$8binary_subscr.2', '$x18.3']
# DEBUG:numba.core.byteflow:dispatch pc=22, inst=BINARY_SUBSCR(arg=None, lineno=1060)
# DEBUG:numba.core.byteflow:stack ['$8binary_subscr.2', '$x18.3', '$const20.4']
# DEBUG:numba.core.byteflow:dispatch pc=32, inst=COMPARE_OP(arg=0, lineno=1060)
# DEBUG:numba.core.byteflow:stack ['$8binary_subscr.2', '$22binary_subscr.5']
# DEBUG:numba.core.byteflow:dispatch pc=38, inst=LOAD_FAST(arg=0, lineno=1060)
# DEBUG:numba.core.byteflow:stack ['$32compare_op.6']
# DEBUG:numba.core.byteflow:dispatch pc=40, inst=LOAD_CONST(arg=1, lineno=1060)
# DEBUG:numba.core.byteflow:stack ['$32compare_op.6', '$x38.7']
# DEBUG:numba.core.byteflow:dispatch pc=42, inst=BINARY_SUBSCR(arg=None, lineno=1060)
# DEBUG:numba.core.byteflow:stack ['$32compare_op.6', '$x38.7', '$const40.8']
# DEBUG:numba.core.byteflow:dispatch pc=52, inst=LOAD_FAST(arg=0, lineno=1060)
# DEBUG:numba.core.byteflow:stack ['$32compare_op.6', '$42binary_subscr.9']
# DEBUG:numba.core.byteflow:dispatch pc=54, inst=LOAD_CONST(arg=3, lineno=1060)
# DEBUG:numba.core.byteflow:stack ['$32compare_op.6', '$42binary_subscr.9', '$x52.10']
# DEBUG:numba.core.byteflow:dispatch pc=56, inst=BINARY_SUBSCR(arg=None, lineno=1060)
# DEBUG:numba.core.byteflow:stack ['$32compare_op.6', '$42binary_subscr.9', '$x52.10', '$const54.11']
# DEBUG:numba.core.byteflow:dispatch pc=66, inst=COMPARE_OP(arg=1, lineno=1060)
# DEBUG:numba.core.byteflow:stack ['$32compare_op.6', '$42binary_subscr.9', '$56binary_subscr.12']
# DEBUG:numba.core.byteflow:dispatch pc=72, inst=BINARY_OP(arg=1, lineno=1060)
# DEBUG:numba.core.byteflow:stack ['$32compare_op.6', '$66compare_op.13']
# DEBUG:numba.core.byteflow:dispatch pc=76, inst=RETURN_VALUE(arg=None, lineno=1060)
# DEBUG:numba.core.byteflow:stack ['$binop_and_72.14']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {}), (4, {'res': '$x4.0'}), (6, {'res': '$const6.1'}), (8, {'index': '$const6.1', 'target': '$x4.0', 'res': '$8binary_subscr.2'}), (10, {}), (12, {}), (14, {}), (16, {}), (18, {'res': '$x18.3'}), (20, {'res': '$const20.4'}), (22, {'index': '$const20.4', 'target': '$x18.3', 'res': '$22binary_subscr.5'}), (24, {}), (26, {}), (28, {}), (30, {}), (32, {'lhs': '$8binary_subscr.2', 'rhs': '$22binary_subscr.5', 'res': '$32compare_op.6'}), (34, {}), (36, {}), (38, {'res': '$x38.7'}), (40, {'res': '$const40.8'}), (42, {'index': '$const40.8', 'target': '$x38.7', 'res': '$42binary_subscr.9'}), (44, {}), (46, {}), (48, {}), (50, {}), (52, {'res': '$x52.10'}), (54, {'res': '$const54.11'}), (56, {'index': '$const54.11', 'target': '$x52.10', 'res': '$56binary_subscr.12'}), (58, {}), (60, {}), (62, {}), (64, {}), (66, {'lhs': '$42binary_subscr.9', 'rhs': '$56binary_subscr.12', 'res': '$66compare_op.13'}), (68, {}), (70, {}), (72, {'op': '&', 'lhs': '$32compare_op.6', 'rhs': '$66compare_op.13', 'res': '$binop_and_72.14'}), (74, {}), (76, {'retval': '$binop_and_72.14', 'castval': '$76return_value.15'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     x = arg(0, name=x)                       ['x']
#     $const6.1 = const(int, 0)                ['$const6.1']
#     $8binary_subscr.2 = getitem(value=x, index=$const6.1, fn=<built-in function getitem>) ['$8binary_subscr.2', '$const6.1', 'x']
#     $const20.4 = const(int, -1)              ['$const20.4']
#     $22binary_subscr.5 = getitem(value=x, index=$const20.4, fn=<built-in function getitem>) ['$22binary_subscr.5', '$const20.4', 'x']
#     $32compare_op.6 = $8binary_subscr.2 < $22binary_subscr.5 ['$22binary_subscr.5', '$32compare_op.6', '$8binary_subscr.2']
#     $const40.8 = const(int, 0)               ['$const40.8']
#     $42binary_subscr.9 = getitem(value=x, index=$const40.8, fn=<built-in function getitem>) ['$42binary_subscr.9', '$const40.8', 'x']
#     $const54.11 = const(int, 1)              ['$const54.11']
#     $56binary_subscr.12 = getitem(value=x, index=$const54.11, fn=<built-in function getitem>) ['$56binary_subscr.12', '$const54.11', 'x']
#     $66compare_op.13 = $42binary_subscr.9 <= $56binary_subscr.12 ['$42binary_subscr.9', '$56binary_subscr.12', '$66compare_op.13']
#     $binop_and_72.14 = $32compare_op.6 & $66compare_op.13 ['$32compare_op.6', '$66compare_op.13', '$binop_and_72.14']
#     $76return_value.15 = cast(value=$binop_and_72.14) ['$76return_value.15', '$binop_and_72.14']
#     return $76return_value.15                ['$76return_value.15']
#
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=4)
#            2	RESUME(arg=0, lineno=4)
#            4	LOAD_FAST(arg=0, lineno=7)
#            6	LOAD_ATTR(arg=0, lineno=7)
#           16	LOAD_CONST(arg=1, lineno=7)
#           18	BINARY_SUBSCR(arg=None, lineno=7)
#           28	STORE_FAST(arg=4, lineno=7)
#           30	LOAD_CONST(arg=2, lineno=8)
#           32	STORE_FAST(arg=5, lineno=8)
#           34	LOAD_GLOBAL(arg=3, lineno=9)
#           46	LOAD_GLOBAL(arg=5, lineno=9)
#           58	LOAD_FAST(arg=4, lineno=9)
#           60	PRECALL(arg=1, lineno=9)
#           64	CALL(arg=1, lineno=9)
#           74	PRECALL(arg=1, lineno=9)
#           78	CALL(arg=1, lineno=9)
#           88	GET_ITER(arg=None, lineno=9)
# >         90	NOP(arg=1, lineno=9)
#           92	FOR_ITER(arg=284, lineno=9)
#           94	STORE_FAST(arg=6, lineno=9)
#           96	LOAD_FAST(arg=0, lineno=10)
#           98	LOAD_FAST(arg=6, lineno=10)
#          100	BINARY_SUBSCR(arg=None, lineno=10)
#          110	STORE_FAST(arg=7, lineno=10)
#          112	LOAD_FAST(arg=1, lineno=11)
#          114	LOAD_FAST(arg=6, lineno=11)
#          116	BINARY_SUBSCR(arg=None, lineno=11)
#          126	STORE_FAST(arg=8, lineno=11)
#          128	LOAD_FAST(arg=2, lineno=12)
#          130	LOAD_FAST(arg=6, lineno=12)
#          132	BINARY_SUBSCR(arg=None, lineno=12)
#          142	STORE_FAST(arg=9, lineno=12)
#          144	LOAD_FAST(arg=3, lineno=13)
#          146	LOAD_FAST(arg=6, lineno=13)
#          148	BINARY_SUBSCR(arg=None, lineno=13)
#          158	STORE_FAST(arg=10, lineno=13)
#          160	LOAD_CONST(arg=3, lineno=15)
#          162	COPY(arg=1, lineno=15)
#          164	STORE_FAST(arg=11, lineno=15)
#          166	STORE_FAST(arg=12, lineno=15)
#          168	LOAD_FAST(arg=10, lineno=16)
#          170	LOAD_CONST(arg=4, lineno=16)
#          172	BINARY_OP(arg=10, lineno=16)
#          176	STORE_FAST(arg=13, lineno=16)
#          178	LOAD_GLOBAL(arg=3, lineno=18)
#          190	LOAD_FAST(arg=9, lineno=18)
#          192	PRECALL(arg=1, lineno=18)
#          196	CALL(arg=1, lineno=18)
#          206	GET_ITER(arg=None, lineno=18)
# >        208	FOR_ITER(arg=146, lineno=18)
#          210	STORE_FAST(arg=14, lineno=18)
#          212	LOAD_GLOBAL(arg=3, lineno=19)
#          224	LOAD_GLOBAL(arg=7, lineno=19)
#          236	LOAD_CONST(arg=1, lineno=19)
#          238	LOAD_FAST(arg=10, lineno=19)
#          240	LOAD_FAST(arg=14, lineno=19)
#          242	BINARY_OP(arg=0, lineno=19)
#          246	LOAD_FAST(arg=9, lineno=19)
#          248	BINARY_OP(arg=10, lineno=19)
#          252	PRECALL(arg=2, lineno=19)
#          256	CALL(arg=2, lineno=19)
#          266	LOAD_GLOBAL(arg=9, lineno=19)
#          278	LOAD_FAST(arg=10, lineno=19)
#          280	LOAD_FAST(arg=14, lineno=19)
#          282	LOAD_CONST(arg=4, lineno=19)
#          284	BINARY_OP(arg=0, lineno=19)
#          288	PRECALL(arg=2, lineno=19)
#          292	CALL(arg=2, lineno=19)
#          302	PRECALL(arg=2, lineno=19)
#          306	CALL(arg=2, lineno=19)
#          316	GET_ITER(arg=None, lineno=19)
# >        318	FOR_ITER(arg=90, lineno=19)
#          320	STORE_FAST(arg=15, lineno=19)
#          322	LOAD_FAST(arg=15, lineno=20)
#          324	LOAD_FAST(arg=14, lineno=20)
#          326	COMPARE_OP(arg=2, lineno=20)
#          332	POP_JUMP_FORWARD_IF_FALSE(arg=3, lineno=20)
#          334	LOAD_FAST(arg=5, lineno=21)
#          336	STORE_FAST(arg=12, lineno=21)
#          338	JUMP_FORWARD(arg=13, lineno=21)
# >        340	LOAD_FAST(arg=8, lineno=23)
#          342	LOAD_FAST(arg=14, lineno=23)
#          344	LOAD_CONST(arg=4, lineno=23)
#          346	BINARY_OP(arg=10, lineno=23)
#          350	LOAD_FAST(arg=15, lineno=23)
#          352	BUILD_TUPLE(arg=2, lineno=23)
#          354	BINARY_SUBSCR(arg=None, lineno=23)
#          364	STORE_FAST(arg=12, lineno=23)
# >        366	LOAD_FAST(arg=15, lineno=24)
#          368	LOAD_CONST(arg=1, lineno=24)
#          370	COMPARE_OP(arg=2, lineno=24)
#          376	POP_JUMP_FORWARD_IF_FALSE(arg=12, lineno=24)
#          378	LOAD_FAST(arg=14, lineno=25)
#          380	LOAD_CONST(arg=1, lineno=25)
#          382	COMPARE_OP(arg=2, lineno=25)
#          388	POP_JUMP_FORWARD_IF_FALSE(arg=3, lineno=25)
#          390	LOAD_CONST(arg=3, lineno=26)
#          392	STORE_FAST(arg=11, lineno=26)
#          394	JUMP_FORWARD(arg=19, lineno=26)
# >        396	LOAD_FAST(arg=5, lineno=28)
#          398	STORE_FAST(arg=11, lineno=28)
#          400	JUMP_FORWARD(arg=16, lineno=28)
# >        402	LOAD_FAST(arg=8, lineno=30)
#          404	LOAD_FAST(arg=14, lineno=30)
#          406	LOAD_CONST(arg=4, lineno=30)
#          408	BINARY_OP(arg=10, lineno=30)
#          412	LOAD_FAST(arg=15, lineno=30)
#          414	LOAD_CONST(arg=4, lineno=30)
#          416	BINARY_OP(arg=10, lineno=30)
#          420	BUILD_TUPLE(arg=2, lineno=30)
#          422	BINARY_SUBSCR(arg=None, lineno=30)
#          432	STORE_FAST(arg=11, lineno=30)
# >        434	LOAD_FAST(arg=8, lineno=31)
#          436	LOAD_FAST(arg=14, lineno=31)
#          438	LOAD_FAST(arg=15, lineno=31)
#          440	BUILD_TUPLE(arg=2, lineno=31)
#          442	COPY(arg=2, lineno=31)
#          444	COPY(arg=2, lineno=31)
#          446	BINARY_SUBSCR(arg=None, lineno=31)
#          456	LOAD_GLOBAL(arg=7, lineno=31)
#          468	LOAD_FAST(arg=11, lineno=31)
#          470	LOAD_FAST(arg=12, lineno=31)
#          472	PRECALL(arg=2, lineno=31)
#          476	CALL(arg=2, lineno=31)
#          486	BINARY_OP(arg=13, lineno=31)
#          490	SWAP(arg=3, lineno=31)
#          492	SWAP(arg=2, lineno=31)
#          494	STORE_SUBSCR(arg=None, lineno=31)
#          498	JUMP_BACKWARD(arg=91, lineno=31)
# >        500	JUMP_BACKWARD(arg=147, lineno=19)
# >        502	LOAD_GLOBAL(arg=3, lineno=33)
#          514	LOAD_FAST(arg=9, lineno=33)
#          516	LOAD_CONST(arg=4, lineno=33)
#          518	BINARY_OP(arg=10, lineno=33)
#          522	LOAD_CONST(arg=5, lineno=33)
#          524	LOAD_CONST(arg=5, lineno=33)
#          526	PRECALL(arg=3, lineno=33)
#          530	CALL(arg=3, lineno=33)
#          540	GET_ITER(arg=None, lineno=33)
# >        542	FOR_ITER(arg=57, lineno=33)
#          544	STORE_FAST(arg=14, lineno=33)
#          546	LOAD_CONST(arg=4, lineno=34)
#          548	LOAD_FAST(arg=7, lineno=34)
#          550	LOAD_FAST(arg=14, lineno=34)
#          552	LOAD_FAST(arg=13, lineno=34)
#          554	BUILD_TUPLE(arg=2, lineno=34)
#          556	STORE_SUBSCR(arg=None, lineno=34)
#          560	LOAD_FAST(arg=13, lineno=35)
#          562	LOAD_CONST(arg=1, lineno=35)
#          564	COMPARE_OP(arg=3, lineno=35)
#          570	POP_JUMP_FORWARD_IF_FALSE(arg=42, lineno=35)
#          572	LOAD_FAST(arg=13, lineno=35)
#          574	LOAD_FAST(arg=14, lineno=35)
#          576	COMPARE_OP(arg=2, lineno=35)
#          582	POP_JUMP_FORWARD_IF_TRUE(arg=31, lineno=35)
#          584	LOAD_FAST(arg=8, lineno=35)
#          586	LOAD_FAST(arg=14, lineno=35)
#          588	LOAD_CONST(arg=4, lineno=35)
#          590	BINARY_OP(arg=10, lineno=35)
#          594	LOAD_FAST(arg=13, lineno=35)
#          596	BUILD_TUPLE(arg=2, lineno=35)
#          598	BINARY_SUBSCR(arg=None, lineno=35)
#          608	LOAD_FAST(arg=8, lineno=35)
#          610	LOAD_FAST(arg=14, lineno=35)
#          612	LOAD_CONST(arg=4, lineno=35)
#          614	BINARY_OP(arg=10, lineno=35)
#          618	LOAD_FAST(arg=13, lineno=35)
#          620	LOAD_CONST(arg=4, lineno=35)
#          622	BINARY_OP(arg=10, lineno=35)
#          626	BUILD_TUPLE(arg=2, lineno=35)
#          628	BINARY_SUBSCR(arg=None, lineno=35)
#          638	COMPARE_OP(arg=0, lineno=35)
#          644	POP_JUMP_FORWARD_IF_FALSE(arg=5, lineno=35)
# >        646	LOAD_FAST(arg=13, lineno=36)
#          648	LOAD_CONST(arg=4, lineno=36)
#          650	BINARY_OP(arg=10, lineno=36)
#          654	STORE_FAST(arg=13, lineno=36)
# >        656	JUMP_BACKWARD(arg=58, lineno=36)
# >        658	NOP(arg=1, lineno=33)
#          660	JUMP_BACKWARD(arg=286, lineno=33)
# >        662	LOAD_CONST(arg=0, lineno=9)
#          664	RETURN_VALUE(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=0 nstack_initial=0)
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=4)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=RESUME(arg=0, lineno=4)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_FAST(arg=0, lineno=7)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=LOAD_ATTR(arg=0, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$paths4.0']
# DEBUG:numba.core.byteflow:dispatch pc=16, inst=LOAD_CONST(arg=1, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$6load_attr.1']
# DEBUG:numba.core.byteflow:dispatch pc=18, inst=BINARY_SUBSCR(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$6load_attr.1', '$const16.2']
# DEBUG:numba.core.byteflow:dispatch pc=28, inst=STORE_FAST(arg=4, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$18binary_subscr.3']
# DEBUG:numba.core.byteflow:dispatch pc=30, inst=LOAD_CONST(arg=2, lineno=8)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=32, inst=STORE_FAST(arg=5, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$const30.4']
# DEBUG:numba.core.byteflow:dispatch pc=34, inst=LOAD_GLOBAL(arg=3, lineno=9)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=46, inst=LOAD_GLOBAL(arg=5, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$null$34.6', '$34load_global.5']
# DEBUG:numba.core.byteflow:dispatch pc=58, inst=LOAD_FAST(arg=4, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$null$34.6', '$34load_global.5', '$null$46.8', '$46load_global.7']
# DEBUG:numba.core.byteflow:dispatch pc=60, inst=PRECALL(arg=1, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$null$34.6', '$34load_global.5', '$null$46.8', '$46load_global.7', '$b58.9']
# DEBUG:numba.core.byteflow:dispatch pc=64, inst=CALL(arg=1, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$null$34.6', '$34load_global.5', '$null$46.8', '$46load_global.7', '$b58.9']
# DEBUG:numba.core.byteflow:dispatch pc=74, inst=PRECALL(arg=1, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$null$34.6', '$34load_global.5', '$64call.10']
# DEBUG:numba.core.byteflow:dispatch pc=78, inst=CALL(arg=1, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$null$34.6', '$34load_global.5', '$64call.10']
# DEBUG:numba.core.byteflow:dispatch pc=88, inst=GET_ITER(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$78call.11']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=90, stack=('$88get_iter.12',), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=90 nstack_initial=1)])
# DEBUG:numba.core.byteflow:stack: ['$phi90.0']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=90 nstack_initial=1)
# DEBUG:numba.core.byteflow:dispatch pc=90, inst=NOP(arg=1, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$phi90.0']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=92, stack=('$phi90.0',), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=92 nstack_initial=1)])
# DEBUG:numba.core.byteflow:stack: ['$phi92.0']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=92 nstack_initial=1)
# DEBUG:numba.core.byteflow:dispatch pc=92, inst=FOR_ITER(arg=284, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$phi92.0']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=662, stack=(), blockstack=(), npush=0), Edge(pc=94, stack=('$phi92.0', '$92for_iter.2'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=662 nstack_initial=0), State(pc_initial=94 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=662 nstack_initial=0)
# DEBUG:numba.core.byteflow:dispatch pc=662, inst=LOAD_CONST(arg=0, lineno=9)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=664, inst=RETURN_VALUE(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$const662.0']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=94 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi94.0', '$phi94.1']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=94 nstack_initial=2)
# DEBUG:numba.core.byteflow:dispatch pc=94, inst=STORE_FAST(arg=6, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$phi94.1']
# DEBUG:numba.core.byteflow:dispatch pc=96, inst=LOAD_FAST(arg=0, lineno=10)
# DEBUG:numba.core.byteflow:stack ['$phi94.0']
# DEBUG:numba.core.byteflow:dispatch pc=98, inst=LOAD_FAST(arg=6, lineno=10)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$paths96.2']
# DEBUG:numba.core.byteflow:dispatch pc=100, inst=BINARY_SUBSCR(arg=None, lineno=10)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$paths96.2', '$i98.3']
# DEBUG:numba.core.byteflow:dispatch pc=110, inst=STORE_FAST(arg=7, lineno=10)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$100binary_subscr.4']
# DEBUG:numba.core.byteflow:dispatch pc=112, inst=LOAD_FAST(arg=1, lineno=11)
# DEBUG:numba.core.byteflow:stack ['$phi94.0']
# DEBUG:numba.core.byteflow:dispatch pc=114, inst=LOAD_FAST(arg=6, lineno=11)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$values112.5']
# DEBUG:numba.core.byteflow:dispatch pc=116, inst=BINARY_SUBSCR(arg=None, lineno=11)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$values112.5', '$i114.6']
# DEBUG:numba.core.byteflow:dispatch pc=126, inst=STORE_FAST(arg=8, lineno=11)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$116binary_subscr.7']
# DEBUG:numba.core.byteflow:dispatch pc=128, inst=LOAD_FAST(arg=2, lineno=12)
# DEBUG:numba.core.byteflow:stack ['$phi94.0']
# DEBUG:numba.core.byteflow:dispatch pc=130, inst=LOAD_FAST(arg=6, lineno=12)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$t_ys128.8']
# DEBUG:numba.core.byteflow:dispatch pc=132, inst=BINARY_SUBSCR(arg=None, lineno=12)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$t_ys128.8', '$i130.9']
# DEBUG:numba.core.byteflow:dispatch pc=142, inst=STORE_FAST(arg=9, lineno=12)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$132binary_subscr.10']
# DEBUG:numba.core.byteflow:dispatch pc=144, inst=LOAD_FAST(arg=3, lineno=13)
# DEBUG:numba.core.byteflow:stack ['$phi94.0']
# DEBUG:numba.core.byteflow:dispatch pc=146, inst=LOAD_FAST(arg=6, lineno=13)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$t_xs144.11']
# DEBUG:numba.core.byteflow:dispatch pc=148, inst=BINARY_SUBSCR(arg=None, lineno=13)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$t_xs144.11', '$i146.12']
# DEBUG:numba.core.byteflow:dispatch pc=158, inst=STORE_FAST(arg=10, lineno=13)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$148binary_subscr.13']
# DEBUG:numba.core.byteflow:dispatch pc=160, inst=LOAD_CONST(arg=3, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$phi94.0']
# DEBUG:numba.core.byteflow:dispatch pc=162, inst=COPY(arg=1, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$const160.14']
# DEBUG:numba.core.byteflow:dispatch pc=164, inst=STORE_FAST(arg=11, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$const160.14', '$const160.14']
# DEBUG:numba.core.byteflow:dispatch pc=166, inst=STORE_FAST(arg=12, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$const160.14']
# DEBUG:numba.core.byteflow:dispatch pc=168, inst=LOAD_FAST(arg=10, lineno=16)
# DEBUG:numba.core.byteflow:stack ['$phi94.0']
# DEBUG:numba.core.byteflow:dispatch pc=170, inst=LOAD_CONST(arg=4, lineno=16)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$t_x168.15']
# DEBUG:numba.core.byteflow:dispatch pc=172, inst=BINARY_OP(arg=10, lineno=16)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$t_x168.15', '$const170.16']
# DEBUG:numba.core.byteflow:dispatch pc=176, inst=STORE_FAST(arg=13, lineno=16)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$binop_sub172.17']
# DEBUG:numba.core.byteflow:dispatch pc=178, inst=LOAD_GLOBAL(arg=3, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi94.0']
# DEBUG:numba.core.byteflow:dispatch pc=190, inst=LOAD_FAST(arg=9, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$null$178.19', '$178load_global.18']
# DEBUG:numba.core.byteflow:dispatch pc=192, inst=PRECALL(arg=1, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$null$178.19', '$178load_global.18', '$t_y190.20']
# DEBUG:numba.core.byteflow:dispatch pc=196, inst=CALL(arg=1, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$null$178.19', '$178load_global.18', '$t_y190.20']
# DEBUG:numba.core.byteflow:dispatch pc=206, inst=GET_ITER(arg=None, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi94.0', '$196call.21']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=208, stack=('$phi94.0', '$206get_iter.22'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=208 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi208.0', '$phi208.1']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=208 nstack_initial=2)
# DEBUG:numba.core.byteflow:dispatch pc=208, inst=FOR_ITER(arg=146, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi208.0', '$phi208.1']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=502, stack=('$phi208.0',), blockstack=(), npush=0), Edge(pc=210, stack=('$phi208.0', '$phi208.1', '$208for_iter.3'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=502 nstack_initial=1), State(pc_initial=210 nstack_initial=3)])
# DEBUG:numba.core.byteflow:stack: ['$phi502.0']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=502 nstack_initial=1)
# DEBUG:numba.core.byteflow:dispatch pc=502, inst=LOAD_GLOBAL(arg=3, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi502.0']
# DEBUG:numba.core.byteflow:dispatch pc=514, inst=LOAD_FAST(arg=9, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi502.0', '$null$502.2', '$502load_global.1']
# DEBUG:numba.core.byteflow:dispatch pc=516, inst=LOAD_CONST(arg=4, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi502.0', '$null$502.2', '$502load_global.1', '$t_y514.3']
# DEBUG:numba.core.byteflow:dispatch pc=518, inst=BINARY_OP(arg=10, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi502.0', '$null$502.2', '$502load_global.1', '$t_y514.3', '$const516.4']
# DEBUG:numba.core.byteflow:dispatch pc=522, inst=LOAD_CONST(arg=5, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi502.0', '$null$502.2', '$502load_global.1', '$binop_sub518.5']
# DEBUG:numba.core.byteflow:dispatch pc=524, inst=LOAD_CONST(arg=5, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi502.0', '$null$502.2', '$502load_global.1', '$binop_sub518.5', '$const522.6']
# DEBUG:numba.core.byteflow:dispatch pc=526, inst=PRECALL(arg=3, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi502.0', '$null$502.2', '$502load_global.1', '$binop_sub518.5', '$const522.6', '$const524.7']
# DEBUG:numba.core.byteflow:dispatch pc=530, inst=CALL(arg=3, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi502.0', '$null$502.2', '$502load_global.1', '$binop_sub518.5', '$const522.6', '$const524.7']
# DEBUG:numba.core.byteflow:dispatch pc=540, inst=GET_ITER(arg=None, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi502.0', '$530call.8']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=542, stack=('$phi502.0', '$540get_iter.9'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=210 nstack_initial=3), State(pc_initial=542 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi210.0', '$phi210.1', '$phi210.2']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=210 nstack_initial=3)
# DEBUG:numba.core.byteflow:dispatch pc=210, inst=STORE_FAST(arg=14, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi210.0', '$phi210.1', '$phi210.2']
# DEBUG:numba.core.byteflow:dispatch pc=212, inst=LOAD_GLOBAL(arg=3, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi210.0', '$phi210.1']
# DEBUG:numba.core.byteflow:dispatch pc=224, inst=LOAD_GLOBAL(arg=7, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi210.0', '$phi210.1', '$null$212.4', '$212load_global.3']
# DEBUG:numba.core.byteflow:dispatch pc=236, inst=LOAD_CONST(arg=1, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi210.0', '$phi210.1', '$null$212.4', '$212load_global.3', '$null$224.6', '$224load_global.5']
# DEBUG:numba.core.byteflow:dispatch pc=238, inst=LOAD_FAST(arg=10, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi210.0', '$phi210.1', '$null$212.4', '$212load_global.3', '$null$224.6', '$224load_global.5', '$const236.7']
# DEBUG:numba.core.byteflow:dispatch pc=240, inst=LOAD_FAST(arg=14, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi210.0', '$phi210.1', '$null$212.4', '$212load_global.3', '$null$224.6', '$224load_global.5', '$const236.7', '$t_x238.8']
# DEBUG:numba.core.byteflow:dispatch pc=242, inst=BINARY_OP(arg=0, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi210.0', '$phi210.1', '$null$212.4', '$212load_global.3', '$null$224.6', '$224load_global.5', '$const236.7', '$t_x238.8', '$y240.9']
# DEBUG:numba.core.byteflow:dispatch pc=246, inst=LOAD_FAST(arg=9, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi210.0', '$phi210.1', '$null$212.4', '$212load_global.3', '$null$224.6', '$224load_global.5', '$const236.7', '$binop_add242.10']
# DEBUG:numba.core.byteflow:dispatch pc=248, inst=BINARY_OP(arg=10, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi210.0', '$phi210.1', '$null$212.4', '$212load_global.3', '$null$224.6', '$224load_global.5', '$const236.7', '$binop_add242.10', '$t_y246.11']
# DEBUG:numba.core.byteflow:dispatch pc=252, inst=PRECALL(arg=2, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi210.0', '$phi210.1', '$null$212.4', '$212load_global.3', '$null$224.6', '$224load_global.5', '$const236.7', '$binop_sub248.12']
# DEBUG:numba.core.byteflow:dispatch pc=256, inst=CALL(arg=2, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi210.0', '$phi210.1', '$null$212.4', '$212load_global.3', '$null$224.6', '$224load_global.5', '$const236.7', '$binop_sub248.12']
# DEBUG:numba.core.byteflow:dispatch pc=266, inst=LOAD_GLOBAL(arg=9, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi210.0', '$phi210.1', '$null$212.4', '$212load_global.3', '$256call.13']
# DEBUG:numba.core.byteflow:dispatch pc=278, inst=LOAD_FAST(arg=10, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi210.0', '$phi210.1', '$null$212.4', '$212load_global.3', '$256call.13', '$null$266.15', '$266load_global.14']
# DEBUG:numba.core.byteflow:dispatch pc=280, inst=LOAD_FAST(arg=14, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi210.0', '$phi210.1', '$null$212.4', '$212load_global.3', '$256call.13', '$null$266.15', '$266load_global.14', '$t_x278.16']
# DEBUG:numba.core.byteflow:dispatch pc=282, inst=LOAD_CONST(arg=4, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi210.0', '$phi210.1', '$null$212.4', '$212load_global.3', '$256call.13', '$null$266.15', '$266load_global.14', '$t_x278.16', '$y280.17']
# DEBUG:numba.core.byteflow:dispatch pc=284, inst=BINARY_OP(arg=0, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi210.0', '$phi210.1', '$null$212.4', '$212load_global.3', '$256call.13', '$null$266.15', '$266load_global.14', '$t_x278.16', '$y280.17', '$const282.18']
# DEBUG:numba.core.byteflow:dispatch pc=288, inst=PRECALL(arg=2, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi210.0', '$phi210.1', '$null$212.4', '$212load_global.3', '$256call.13', '$null$266.15', '$266load_global.14', '$t_x278.16', '$binop_add284.19']
# DEBUG:numba.core.byteflow:dispatch pc=292, inst=CALL(arg=2, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi210.0', '$phi210.1', '$null$212.4', '$212load_global.3', '$256call.13', '$null$266.15', '$266load_global.14', '$t_x278.16', '$binop_add284.19']
# DEBUG:numba.core.byteflow:dispatch pc=302, inst=PRECALL(arg=2, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi210.0', '$phi210.1', '$null$212.4', '$212load_global.3', '$256call.13', '$292call.20']
# DEBUG:numba.core.byteflow:dispatch pc=306, inst=CALL(arg=2, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi210.0', '$phi210.1', '$null$212.4', '$212load_global.3', '$256call.13', '$292call.20']
# DEBUG:numba.core.byteflow:dispatch pc=316, inst=GET_ITER(arg=None, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi210.0', '$phi210.1', '$306call.21']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=318, stack=('$phi210.0', '$phi210.1', '$316get_iter.22'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=542 nstack_initial=2), State(pc_initial=318 nstack_initial=3)])
# DEBUG:numba.core.byteflow:stack: ['$phi542.0', '$phi542.1']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=542 nstack_initial=2)
# DEBUG:numba.core.byteflow:dispatch pc=542, inst=FOR_ITER(arg=57, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi542.0', '$phi542.1']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=658, stack=('$phi542.0',), blockstack=(), npush=0), Edge(pc=544, stack=('$phi542.0', '$phi542.1', '$542for_iter.3'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=318 nstack_initial=3), State(pc_initial=658 nstack_initial=1), State(pc_initial=544 nstack_initial=3)])
# DEBUG:numba.core.byteflow:stack: ['$phi318.0', '$phi318.1', '$phi318.2']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=318 nstack_initial=3)
# DEBUG:numba.core.byteflow:dispatch pc=318, inst=FOR_ITER(arg=90, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi318.0', '$phi318.1', '$phi318.2']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=500, stack=('$phi318.0', '$phi318.1'), blockstack=(), npush=0), Edge(pc=320, stack=('$phi318.0', '$phi318.1', '$phi318.2', '$318for_iter.4'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=658 nstack_initial=1), State(pc_initial=544 nstack_initial=3), State(pc_initial=500 nstack_initial=2), State(pc_initial=320 nstack_initial=4)])
# DEBUG:numba.core.byteflow:stack: ['$phi658.0']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=658 nstack_initial=1)
# DEBUG:numba.core.byteflow:dispatch pc=658, inst=NOP(arg=1, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi658.0']
# DEBUG:numba.core.byteflow:dispatch pc=660, inst=JUMP_BACKWARD(arg=286, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi658.0']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=90, stack=('$phi658.0',), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=544 nstack_initial=3), State(pc_initial=500 nstack_initial=2), State(pc_initial=320 nstack_initial=4), State(pc_initial=90 nstack_initial=1)])
# DEBUG:numba.core.byteflow:stack: ['$phi544.0', '$phi544.1', '$phi544.2']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=544 nstack_initial=3)
# DEBUG:numba.core.byteflow:dispatch pc=544, inst=STORE_FAST(arg=14, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi544.0', '$phi544.1', '$phi544.2']
# DEBUG:numba.core.byteflow:dispatch pc=546, inst=LOAD_CONST(arg=4, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$phi544.0', '$phi544.1']
# DEBUG:numba.core.byteflow:dispatch pc=548, inst=LOAD_FAST(arg=7, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$phi544.0', '$phi544.1', '$const546.3']
# DEBUG:numba.core.byteflow:dispatch pc=550, inst=LOAD_FAST(arg=14, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$phi544.0', '$phi544.1', '$const546.3', '$path548.4']
# DEBUG:numba.core.byteflow:dispatch pc=552, inst=LOAD_FAST(arg=13, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$phi544.0', '$phi544.1', '$const546.3', '$path548.4', '$y550.5']
# DEBUG:numba.core.byteflow:dispatch pc=554, inst=BUILD_TUPLE(arg=2, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$phi544.0', '$phi544.1', '$const546.3', '$path548.4', '$y550.5', '$index552.6']
# DEBUG:numba.core.byteflow:dispatch pc=556, inst=STORE_SUBSCR(arg=None, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$phi544.0', '$phi544.1', '$const546.3', '$path548.4', '$554build_tuple.7']
# DEBUG:numba.core.byteflow:dispatch pc=560, inst=LOAD_FAST(arg=13, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi544.0', '$phi544.1']
# DEBUG:numba.core.byteflow:dispatch pc=562, inst=LOAD_CONST(arg=1, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi544.0', '$phi544.1', '$index560.8']
# DEBUG:numba.core.byteflow:dispatch pc=564, inst=COMPARE_OP(arg=3, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi544.0', '$phi544.1', '$index560.8', '$const562.9']
# DEBUG:numba.core.byteflow:dispatch pc=570, inst=POP_JUMP_FORWARD_IF_FALSE(arg=42, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi544.0', '$phi544.1', '$564compare_op.10']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=572, stack=('$phi544.0', '$phi544.1'), blockstack=(), npush=0), Edge(pc=656, stack=('$phi544.0', '$phi544.1'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=500 nstack_initial=2), State(pc_initial=320 nstack_initial=4), State(pc_initial=90 nstack_initial=1), State(pc_initial=572 nstack_initial=2), State(pc_initial=656 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi500.0', '$phi500.1']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=500 nstack_initial=2)
# DEBUG:numba.core.byteflow:dispatch pc=500, inst=JUMP_BACKWARD(arg=147, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi500.0', '$phi500.1']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=208, stack=('$phi500.0', '$phi500.1'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=320 nstack_initial=4), State(pc_initial=90 nstack_initial=1), State(pc_initial=572 nstack_initial=2), State(pc_initial=656 nstack_initial=2), State(pc_initial=208 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi320.0', '$phi320.1', '$phi320.2', '$phi320.3']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=320 nstack_initial=4)
# DEBUG:numba.core.byteflow:dispatch pc=320, inst=STORE_FAST(arg=15, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi320.0', '$phi320.1', '$phi320.2', '$phi320.3']
# DEBUG:numba.core.byteflow:dispatch pc=322, inst=LOAD_FAST(arg=15, lineno=20)
# DEBUG:numba.core.byteflow:stack ['$phi320.0', '$phi320.1', '$phi320.2']
# DEBUG:numba.core.byteflow:dispatch pc=324, inst=LOAD_FAST(arg=14, lineno=20)
# DEBUG:numba.core.byteflow:stack ['$phi320.0', '$phi320.1', '$phi320.2', '$x322.4']
# DEBUG:numba.core.byteflow:dispatch pc=326, inst=COMPARE_OP(arg=2, lineno=20)
# DEBUG:numba.core.byteflow:stack ['$phi320.0', '$phi320.1', '$phi320.2', '$x322.4', '$y324.5']
# DEBUG:numba.core.byteflow:dispatch pc=332, inst=POP_JUMP_FORWARD_IF_FALSE(arg=3, lineno=20)
# DEBUG:numba.core.byteflow:stack ['$phi320.0', '$phi320.1', '$phi320.2', '$326compare_op.6']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=334, stack=('$phi320.0', '$phi320.1', '$phi320.2'), blockstack=(), npush=0), Edge(pc=340, stack=('$phi320.0', '$phi320.1', '$phi320.2'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=90 nstack_initial=1), State(pc_initial=572 nstack_initial=2), State(pc_initial=656 nstack_initial=2), State(pc_initial=208 nstack_initial=2), State(pc_initial=334 nstack_initial=3), State(pc_initial=340 nstack_initial=3)])
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=572 nstack_initial=2), State(pc_initial=656 nstack_initial=2), State(pc_initial=208 nstack_initial=2), State(pc_initial=334 nstack_initial=3), State(pc_initial=340 nstack_initial=3)])
# DEBUG:numba.core.byteflow:stack: ['$phi572.0', '$phi572.1']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=572 nstack_initial=2)
# DEBUG:numba.core.byteflow:dispatch pc=572, inst=LOAD_FAST(arg=13, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi572.0', '$phi572.1']
# DEBUG:numba.core.byteflow:dispatch pc=574, inst=LOAD_FAST(arg=14, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi572.0', '$phi572.1', '$index572.2']
# DEBUG:numba.core.byteflow:dispatch pc=576, inst=COMPARE_OP(arg=2, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi572.0', '$phi572.1', '$index572.2', '$y574.3']
# DEBUG:numba.core.byteflow:dispatch pc=582, inst=POP_JUMP_FORWARD_IF_TRUE(arg=31, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi572.0', '$phi572.1', '$576compare_op.4']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=584, stack=('$phi572.0', '$phi572.1'), blockstack=(), npush=0), Edge(pc=646, stack=('$phi572.0', '$phi572.1'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=656 nstack_initial=2), State(pc_initial=208 nstack_initial=2), State(pc_initial=334 nstack_initial=3), State(pc_initial=340 nstack_initial=3), State(pc_initial=584 nstack_initial=2), State(pc_initial=646 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi656.0', '$phi656.1']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=656 nstack_initial=2)
# DEBUG:numba.core.byteflow:dispatch pc=656, inst=JUMP_BACKWARD(arg=58, lineno=36)
# DEBUG:numba.core.byteflow:stack ['$phi656.0', '$phi656.1']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=542, stack=('$phi656.0', '$phi656.1'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=208 nstack_initial=2), State(pc_initial=334 nstack_initial=3), State(pc_initial=340 nstack_initial=3), State(pc_initial=584 nstack_initial=2), State(pc_initial=646 nstack_initial=2), State(pc_initial=542 nstack_initial=2)])
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=334 nstack_initial=3), State(pc_initial=340 nstack_initial=3), State(pc_initial=584 nstack_initial=2), State(pc_initial=646 nstack_initial=2), State(pc_initial=542 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi334.0', '$phi334.1', '$phi334.2']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=334 nstack_initial=3)
# DEBUG:numba.core.byteflow:dispatch pc=334, inst=LOAD_FAST(arg=5, lineno=21)
# DEBUG:numba.core.byteflow:stack ['$phi334.0', '$phi334.1', '$phi334.2']
# DEBUG:numba.core.byteflow:dispatch pc=336, inst=STORE_FAST(arg=12, lineno=21)
# DEBUG:numba.core.byteflow:stack ['$phi334.0', '$phi334.1', '$phi334.2', '$max_neg_val334.3']
# DEBUG:numba.core.byteflow:dispatch pc=338, inst=JUMP_FORWARD(arg=13, lineno=21)
# DEBUG:numba.core.byteflow:stack ['$phi334.0', '$phi334.1', '$phi334.2']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=366, stack=('$phi334.0', '$phi334.1', '$phi334.2'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=340 nstack_initial=3), State(pc_initial=584 nstack_initial=2), State(pc_initial=646 nstack_initial=2), State(pc_initial=542 nstack_initial=2), State(pc_initial=366 nstack_initial=3)])
# DEBUG:numba.core.byteflow:stack: ['$phi340.0', '$phi340.1', '$phi340.2']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=340 nstack_initial=3)
# DEBUG:numba.core.byteflow:dispatch pc=340, inst=LOAD_FAST(arg=8, lineno=23)
# ...
# DEBUG:numba.core.ssa:on stmt: $316get_iter.22 = getiter(value=$306call.21)
# DEBUG:numba.core.ssa:on stmt: $phi318.2 = $316get_iter.22
# DEBUG:numba.core.ssa:on stmt: jump 318
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 318
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x000002F6E756C950>
# DEBUG:numba.core.ssa:on stmt: $318for_iter.3 = iternext(value=$phi318.2)
# DEBUG:numba.core.ssa:on stmt: $318for_iter.4 = pair_first(value=$318for_iter.3)
# DEBUG:numba.core.ssa:on stmt: $318for_iter.5 = pair_second(value=$318for_iter.3)
# DEBUG:numba.core.ssa:on stmt: $phi320.3 = $318for_iter.4
# DEBUG:numba.core.ssa:on stmt: branch $318for_iter.5, 320, 500
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 320
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x000002F6E756C950>
# DEBUG:numba.core.ssa:on stmt: x = $phi320.3
# DEBUG:numba.core.ssa:on stmt: $326compare_op.6 = x == y
# DEBUG:numba.core.ssa:find_def var='y' stmt=$326compare_op.6 = x == y
# DEBUG:numba.core.ssa:find_def_from_top label 320
# DEBUG:numba.core.ssa:idom 318 from label 320
# DEBUG:numba.core.ssa:find_def_from_bottom label 318
# DEBUG:numba.core.ssa:find_def_from_top label 318
# DEBUG:numba.core.ssa:idom 210 from label 318
# DEBUG:numba.core.ssa:find_def_from_bottom label 210
# DEBUG:numba.core.ssa:on stmt: bool332 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $332pred = call bool332($326compare_op.6, func=bool332, args=(Var($326compare_op.6, core.py:20),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $332pred, 334, 340
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 334
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x000002F6E756C950>
# DEBUG:numba.core.ssa:on stmt: v_cur.1 = max_neg_val
# DEBUG:numba.core.ssa:on stmt: jump 366
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 340
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x000002F6E756C950>
# DEBUG:numba.core.ssa:on stmt: $const344.5 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $binop_sub346.6 = y - $const344.5
# DEBUG:numba.core.ssa:find_def var='y' stmt=$binop_sub346.6 = y - $const344.5
# DEBUG:numba.core.ssa:find_def_from_top label 340
# DEBUG:numba.core.ssa:idom 320 from label 340
# DEBUG:numba.core.ssa:find_def_from_bottom label 320
# DEBUG:numba.core.ssa:find_def_from_top label 320
# DEBUG:numba.core.ssa:idom 318 from label 320
# DEBUG:numba.core.ssa:find_def_from_bottom label 318
# DEBUG:numba.core.ssa:find_def_from_top label 318
# DEBUG:numba.core.ssa:idom 210 from label 318
# DEBUG:numba.core.ssa:find_def_from_bottom label 210
# DEBUG:numba.core.ssa:on stmt: $352build_tuple.8 = build_tuple(items=[Var($binop_sub346.6, core.py:23), Var(x, core.py:19)])
# DEBUG:numba.core.ssa:on stmt: v_cur.2 = getitem(value=value, index=$352build_tuple.8, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: jump 366
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 366
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x000002F6E756C950>
# DEBUG:numba.core.ssa:on stmt: v_cur.3 = phi(incoming_values=[Var(v_cur.2, core.py:23), Var(v_cur.1, core.py:21)], incoming_blocks=[340, 334])
# DEBUG:numba.core.ssa:on stmt: $const368.4 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $370compare_op.5 = x == $const368.4
# DEBUG:numba.core.ssa:on stmt: bool376 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $376pred = call bool376($370compare_op.5, func=bool376, args=(Var($370compare_op.5, core.py:24),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $376pred, 378, 402
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 378
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x000002F6E756C950>
# DEBUG:numba.core.ssa:on stmt: $const380.4 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $382compare_op.5 = y == $const380.4
# DEBUG:numba.core.ssa:find_def var='y' stmt=$382compare_op.5 = y == $const380.4
# DEBUG:numba.core.ssa:find_def_from_top label 378
# DEBUG:numba.core.ssa:idom 366 from label 378
# DEBUG:numba.core.ssa:find_def_from_bottom label 366
# DEBUG:numba.core.ssa:find_def_from_top label 366
# DEBUG:numba.core.ssa:idom 320 from label 366
# DEBUG:numba.core.ssa:find_def_from_bottom label 320
# DEBUG:numba.core.ssa:find_def_from_top label 320
# DEBUG:numba.core.ssa:idom 318 from label 320
# DEBUG:numba.core.ssa:find_def_from_bottom label 318
# DEBUG:numba.core.ssa:find_def_from_top label 318
# DEBUG:numba.core.ssa:idom 210 from label 318
# DEBUG:numba.core.ssa:find_def_from_bottom label 210
# DEBUG:numba.core.ssa:on stmt: bool388 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $388pred = call bool388($382compare_op.5, func=bool388, args=(Var($382compare_op.5, core.py:25),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $388pred, 390, 396
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 390
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x000002F6E756C950>
# DEBUG:numba.core.ssa:on stmt: v_prev.1 = const(float, 0.0)
# DEBUG:numba.core.ssa:on stmt: jump 434
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 396
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x000002F6E756C950>
# DEBUG:numba.core.ssa:on stmt: v_prev.2 = max_neg_val
# DEBUG:numba.core.ssa:on stmt: jump 434
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 402
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x000002F6E756C950>
# DEBUG:numba.core.ssa:on stmt: $const406.5 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $binop_sub408.6 = y - $const406.5
# DEBUG:numba.core.ssa:find_def var='y' stmt=$binop_sub408.6 = y - $const406.5
# DEBUG:numba.core.ssa:find_def_from_top label 402
# DEBUG:numba.core.ssa:idom 366 from label 402
# DEBUG:numba.core.ssa:find_def_from_bottom label 366
# DEBUG:numba.core.ssa:find_def_from_top label 366
# DEBUG:numba.core.ssa:idom 320 from label 366
# DEBUG:numba.core.ssa:find_def_from_bottom label 320
# DEBUG:numba.core.ssa:find_def_from_top label 320
# DEBUG:numba.core.ssa:idom 318 from label 320
# DEBUG:numba.core.ssa:find_def_from_bottom label 318
# DEBUG:numba.core.ssa:find_def_from_top label 318
# DEBUG:numba.core.ssa:idom 210 from label 318
# DEBUG:numba.core.ssa:find_def_from_bottom label 210
# DEBUG:numba.core.ssa:on stmt: $const414.8 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $binop_sub416.9 = x - $const414.8
# DEBUG:numba.core.ssa:on stmt: $420build_tuple.10 = build_tuple(items=[Var($binop_sub408.6, core.py:30), Var($binop_sub416.9, core.py:30)])
# DEBUG:numba.core.ssa:on stmt: v_prev.3 = getitem(value=value, index=$420build_tuple.10, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: jump 434
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 434
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x000002F6E756C950>
# DEBUG:numba.core.ssa:on stmt: v_prev.4 = phi(incoming_values=[Var(v_prev.3, core.py:30), Var(v_prev.2, core.py:28), Var(v_prev.1, core.py:26)], incoming_blocks=[402, 396, 390])
# DEBUG:numba.core.ssa:on stmt: $440build_tuple.6 = build_tuple(items=[Var(y, core.py:18), Var(x, core.py:19)])
# DEBUG:numba.core.ssa:find_def var='y' stmt=$440build_tuple.6 = build_tuple(items=[Var(y, core.py:18), Var(x, core.py:19)])
# DEBUG:numba.core.ssa:find_def_from_top label 434
# DEBUG:numba.core.ssa:idom 366 from label 434
# DEBUG:numba.core.ssa:find_def_from_bottom label 366
# DEBUG:numba.core.ssa:find_def_from_top label 366
# DEBUG:numba.core.ssa:idom 320 from label 366
# DEBUG:numba.core.ssa:find_def_from_bottom label 320
# DEBUG:numba.core.ssa:find_def_from_top label 320
# DEBUG:numba.core.ssa:idom 318 from label 320
# DEBUG:numba.core.ssa:find_def_from_bottom label 318
# DEBUG:numba.core.ssa:find_def_from_top label 318
# DEBUG:numba.core.ssa:idom 210 from label 318
# DEBUG:numba.core.ssa:find_def_from_bottom label 210
# DEBUG:numba.core.ssa:on stmt: $446binary_subscr.7 = getitem(value=value, index=$440build_tuple.6, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $456load_global.8 = global(max: <built-in function max>)
# DEBUG:numba.core.ssa:on stmt: $476call.12 = call $456load_global.8(v_prev.4, v_cur.3, func=$456load_global.8, args=[Var(v_prev.4, core.py:31), Var(v_cur.3, core.py:31)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: $binop_iadd486.13 = inplace_binop(fn=<built-in function iadd>, immutable_fn=<built-in function add>, lhs=$446binary_subscr.7, rhs=$476call.12, static_lhs=Undefined, static_rhs=Undefined)
# DEBUG:numba.core.ssa:on stmt: value[$440build_tuple.6] = $binop_iadd486.13
# DEBUG:numba.core.ssa:on stmt: jump 318
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 500
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x000002F6E756C950>
# DEBUG:numba.core.ssa:on stmt: jump 208
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 502
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x000002F6E756C950>
# DEBUG:numba.core.ssa:on stmt: $502load_global.1 = global(range: <class 'range'>)
# DEBUG:numba.core.ssa:on stmt: $const516.4 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $binop_sub518.5 = t_y - $const516.4
# DEBUG:numba.core.ssa:on stmt: $const522.6 = const(int, -1)
# DEBUG:numba.core.ssa:on stmt: $const524.7 = const(int, -1)
# DEBUG:numba.core.ssa:on stmt: $530call.8 = call $502load_global.1($binop_sub518.5, $const522.6, $const524.7, func=$502load_global.1, args=[Var($binop_sub518.5, core.py:33), Var($const522.6, core.py:33), Var($const524.7, core.py:33)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: $540get_iter.9 = getiter(value=$530call.8)
# DEBUG:numba.core.ssa:on stmt: $phi542.1 = $540get_iter.9
# DEBUG:numba.core.ssa:on stmt: jump 542
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 542
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x000002F6E756C950>
# DEBUG:numba.core.ssa:on stmt: index.2 = phi(incoming_values=[Var(index.3, core.py:33), Var(index, core.py:16)], incoming_blocks=[656, 502])
# DEBUG:numba.core.ssa:on stmt: $542for_iter.2 = iternext(value=$phi542.1)
# DEBUG:numba.core.ssa:on stmt: $542for_iter.3 = pair_first(value=$542for_iter.2)
# DEBUG:numba.core.ssa:on stmt: $542for_iter.4 = pair_second(value=$542for_iter.2)
# DEBUG:numba.core.ssa:on stmt: $phi544.2 = $542for_iter.3
# DEBUG:numba.core.ssa:on stmt: branch $542for_iter.4, 544, 658
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 544
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x000002F6E756C950>
# DEBUG:numba.core.ssa:on stmt: y.1 = $phi544.2
# DEBUG:numba.core.ssa:on stmt: $const546.3 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $554build_tuple.7 = build_tuple(items=[Var(y, core.py:18), Var(index.2, core.py:33)])
# DEBUG:numba.core.ssa:find_def var='y' stmt=$554build_tuple.7 = build_tuple(items=[Var(y, core.py:18), Var(index.2, core.py:33)])
# DEBUG:numba.core.ssa:replaced with: $554build_tuple.7 = build_tuple(items=[Var(y.1, core.py:33), Var(index.2, core.py:33)])
# DEBUG:numba.core.ssa:on stmt: path[$554build_tuple.7] = $const546.3
# DEBUG:numba.core.ssa:on stmt: $const562.9 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $564compare_op.10 = index.2 != $const562.9
# DEBUG:numba.core.ssa:on stmt: bool570 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $570pred = call bool570($564compare_op.10, func=bool570, args=(Var($564compare_op.10, core.py:35),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $570pred, 572, 656
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 572
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x000002F6E756C950>
# DEBUG:numba.core.ssa:on stmt: $576compare_op.4 = index.2 == y
# DEBUG:numba.core.ssa:find_def var='y' stmt=$576compare_op.4 = index.2 == y
# DEBUG:numba.core.ssa:find_def_from_top label 572
# DEBUG:numba.core.ssa:idom 544 from label 572
# DEBUG:numba.core.ssa:find_def_from_bottom label 544
# DEBUG:numba.core.ssa:replaced with: $576compare_op.4 = index.2 == y.1
# DEBUG:numba.core.ssa:on stmt: bool582 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $582pred = call bool582($576compare_op.4, func=bool582, args=(Var($576compare_op.4, core.py:35),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $582pred, 646, 584
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 584
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x000002F6E756C950>
# DEBUG:numba.core.ssa:on stmt: $const588.4 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $binop_sub590.5 = y - $const588.4
# DEBUG:numba.core.ssa:find_def var='y' stmt=$binop_sub590.5 = y - $const588.4
# DEBUG:numba.core.ssa:find_def_from_top label 584
# DEBUG:numba.core.ssa:idom 572 from label 584
# DEBUG:numba.core.ssa:find_def_from_bottom label 572
# DEBUG:numba.core.ssa:find_def_from_top label 572
# DEBUG:numba.core.ssa:idom 544 from label 572
# DEBUG:numba.core.ssa:find_def_from_bottom label 544
# DEBUG:numba.core.ssa:replaced with: $binop_sub590.5 = y.1 - $const588.4
# DEBUG:numba.core.ssa:on stmt: $596build_tuple.7 = build_tuple(items=[Var($binop_sub590.5, core.py:35), Var(index.2, core.py:33)])
# DEBUG:numba.core.ssa:on stmt: $598binary_subscr.8 = getitem(value=value, index=$596build_tuple.7, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $const612.11 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $binop_sub614.12 = y - $const612.11
# DEBUG:numba.core.ssa:find_def var='y' stmt=$binop_sub614.12 = y - $const612.11
# DEBUG:numba.core.ssa:find_def_from_top label 584
# DEBUG:numba.core.ssa:idom 572 from label 584
# DEBUG:numba.core.ssa:find_def_from_bottom label 572
# DEBUG:numba.core.ssa:find_def_from_top label 572
# DEBUG:numba.core.ssa:idom 544 from label 572
# DEBUG:numba.core.ssa:find_def_from_bottom label 544
# DEBUG:numba.core.ssa:replaced with: $binop_sub614.12 = y.1 - $const612.11
# DEBUG:numba.core.ssa:on stmt: $const620.14 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $binop_sub622.15 = index.2 - $const620.14
# DEBUG:numba.core.ssa:on stmt: $626build_tuple.16 = build_tuple(items=[Var($binop_sub614.12, core.py:35), Var($binop_sub622.15, core.py:35)])
# DEBUG:numba.core.ssa:on stmt: $628binary_subscr.17 = getitem(value=value, index=$626build_tuple.16, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $638compare_op.18 = $598binary_subscr.8 < $628binary_subscr.17
# DEBUG:numba.core.ssa:on stmt: bool644 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $644pred = call bool644($638compare_op.18, func=bool644, args=(Var($638compare_op.18, core.py:35),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $644pred, 646, 656
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 646
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x000002F6E756C950>
# DEBUG:numba.core.ssa:on stmt: $const648.3 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $binop_sub650.4 = index.2 - $const648.3
# DEBUG:numba.core.ssa:on stmt: index.1 = $binop_sub650.4
# DEBUG:numba.core.ssa:on stmt: jump 656
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 656
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x000002F6E756C950>
# DEBUG:numba.core.ssa:on stmt: index.3 = phi(incoming_values=[Var(index.2, core.py:33), Var(index.2, core.py:33), Var(index.1, core.py:36)], incoming_blocks=[544, 584, 646])
# DEBUG:numba.core.ssa:on stmt: jump 542
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 658
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x000002F6E756C950>
# DEBUG:numba.core.ssa:on stmt: jump 90
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 662
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x000002F6E756C950>
# DEBUG:numba.core.ssa:on stmt: $const662.0 = const(NoneType, None)
# DEBUG:numba.core.ssa:on stmt: $664return_value.1 = cast(value=$const662.0)
# DEBUG:numba.core.ssa:on stmt: return $664return_value.1

# %% [markdown]
# ## Single Speaker

# %%
hps = utils.get_hparams_from_file("C:/Users/ADMIN/Desktop/VIT-vn/vits-vn/configs/vietnamese_base.json")

# %%
net_g = SynthesizerTrn(
    len(symbols),
    hps.data.filter_length // 2 + 1,
    hps.train.segment_size // hps.data.hop_length,
    **hps.model).cpu()
_ = net_g.eval()

_ = utils.load_checkpoint("G:/download/G_last.pth", net_g, None)
# Out:
# INFO:root:Loaded checkpoint 'G:/download/G_last.pth' (iteration 18)

# %%
stn_tst = get_text("hi hi", hps)
with torch.no_grad():
    x_tst = stn_tst.cuda().unsqueeze(0)
    x_tst_lengths = torch.LongTensor([stn_tst.size(0)]).cuda()
    audio = net_g.infer(x_tst, x_tst_lengths, noise_scale=.667, noise_scale_w=0.8, length_scale=1)[0][0,0].data.cpu().float().numpy()
ipd.display(ipd.Audio(audio, rate=hps.data.sampling_rate, normalize=False))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 stn_tst = get_text("hi hi", hps)
#       2 with torch.no_grad():
#       3     x_tst = stn_tst.cuda().unsqueeze(0)
#
# Cell In[1], line 24, in get_text(text, hps)
#      23 def get_text(text, hps):
# ---> 24     text_norm = text_to_sequence(text, hps.data.text_cleaners)
#      25     if hps.data.add_blank:
#      26         text_norm = commons.intersperse(text_norm, 0)
#
# File ~\Desktop\VIT-vn\vits-vn\text\__init__.py:21, in text_to_sequence(text, cleaner_names)
#      12 '''Converts a string of text to a sequence of IDs corresponding to the symbols in the text.
#      13   Args:
#      14     text: string to convert to a sequence
#    (...)
#      17     List of integers corresponding to the symbols in the text
#      18 '''
#      19 sequence = []
# ---> 21 clean_text = _clean_text(text, cleaner_names)
#      22 for symbol in clean_text:
#      23   if symbol not in _symbol_to_id.keys():
#
# File ~\Desktop\VIT-vn\vits-vn\text\__init__.py:55, in _clean_text(text, cleaner_names)
#      53   if not cleaner:
#      54     raise Exception('Unknown cleaner: %s' % name)
# ---> 55   text = cleaner(text)
#      56 return text
#
# File ~\Desktop\VIT-vn\vits-vn\text\cleaners.py:15, in vietnamese_cleaners(text)
#      13 text = re.sub(r'[^\w\s\u00C0-\u1EF9]', '', text)
#      14 text = re.sub(r'([\.,!\?\-…~ ])$', r'\1', text)
# ---> 15 text = vi_to_ipa(text) #.replace('...', '…')
#      16 # text = re.sub(r'([A-Za-z])$', r'\1.', text)
#      18 return text
#
# File ~\Desktop\VIT-vn\vits-vn\text\vietnamese.py:23, in vi_to_ipa(text)
#      21 text = text.lower()
#      22 text = text_normalize(text)
# ---> 23 phonemes = vi2IPA(text)
#      24 phonemes = collapse_whitespace(phonemes)
#      25 return phonemes
#
# File ~\Desktop\VIT-vn\vits-vn\venv\Lib\site-packages\viphoneme\__init__.py:578, in vi2IPA(text)
#     576 def vi2IPA(text):
#     577     #print("------------------------------------------------------")
# --> 578     TN= TTSnorm(text)
#     579     #print("------------------------------------------------------")
#     580     #print("Text normalize:              ",TN)
#     581     TK= word_tokenize(TN)
#
# File ~\Desktop\VIT-vn\vits-vn\venv\Lib\site-packages\vinorm\__init__.py:25, in TTSnorm(text, punc, unknown, lower, rule)
#      23 if rule:
#      24     Command.append("-rule")
# ---> 25 subprocess.check_call(Command, env=myenv, cwd=A)
#      27 O=A+"/output.txt"
#      28 with open(O,"r") as fr:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\subprocess.py:408, in check_call(*popenargs, **kwargs)
#     398 def check_call(*popenargs, **kwargs):
#     399     """Run command with arguments.  Wait for command to complete.  If
#     400     the exit code was zero then return, otherwise raise
#     401     CalledProcessError.  The CalledProcessError object will have the
#    (...)
#     406     check_call(["ls", "-l"])
#     407     """
# --> 408     retcode = call(*popenargs, **kwargs)
#     409     if retcode:
#     410         cmd = kwargs.get("args")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\subprocess.py:389, in call(timeout, *popenargs, **kwargs)
#     381 def call(*popenargs, timeout=None, **kwargs):
#     382     """Run command with arguments.  Wait for command to complete or
#     383     timeout, then return the returncode attribute.
#     384
#    (...)
#     387     retcode = call(["ls", "-l"])
#     388     """
# --> 389     with Popen(*popenargs, **kwargs) as p:
#     390         try:
#     391             return p.wait(timeout=timeout)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\subprocess.py:1022, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1018         if self.text_mode:
#    1019             self.stderr = io.TextIOWrapper(self.stderr,
#    1020                     encoding=encoding, errors=errors)
# -> 1022     self._execute_child(args, executable, preexec_fn, close_fds,
#    1023                         pass_fds, cwd, env,
#    1024                         startupinfo, creationflags, shell,
#    1025                         p2cread, p2cwrite,
#    1026                         c2pread, c2pwrite,
#    1027                         errread, errwrite,
#    1028                         restore_signals,
#    1029                         gid, gids, uid, umask,
#    1030                         start_new_session, process_group)
#    1031 except:
#    1032     # Cleanup if the child failed starting.
#    1033     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\subprocess.py:1491, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1489 # Start the process
#    1490 try:
# -> 1491     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1492                              # no special security
#    1493                              None, None,
#    1494                              int(not close_fds),
#    1495                              creationflags,
#    1496                              env,
#    1497                              cwd,
#    1498                              startupinfo)
#    1499 finally:
#    1500     # Child is launched. Close the parent's copy of those pipe
#    1501     # handles that only the child should have open.  You need
#    (...)
#    1504     # pipe will not close when the child process exits and the
#    1505     # ReadFile will hang.
#    1506     self._close_pipe_fds(p2cread, p2cwrite,
#    1507                          c2pread, c2pwrite,
#    1508                          errread, errwrite)
#
# OSError: [WinError 193] %1 is not a valid Win32 application

# %% [markdown]
# ## Multiple Speakers

# %%
hps = utils.get_hparams_from_file("./configs/XXX.json")

# %%
net_g = SynthesizerTrn(
    len(symbols),
    hps.data.filter_length // 2 + 1,
    hps.train.segment_size // hps.data.hop_length,
    n_speakers=hps.data.n_speakers,
    **hps.model).cuda()
_ = net_g.eval()

_ = utils.load_checkpoint("/path/to/model.pth", net_g, None)

# %%
stn_tst = get_text("こんにちは", hps)
with torch.no_grad():
    x_tst = stn_tst.cuda().unsqueeze(0)
    x_tst_lengths = torch.LongTensor([stn_tst.size(0)]).cuda()
    sid = torch.LongTensor([4]).cuda()
    audio = net_g.infer(x_tst, x_tst_lengths, sid=sid, noise_scale=.667, noise_scale_w=0.8, length_scale=1)[0][0,0].data.cpu().float().numpy()
ipd.display(ipd.Audio(audio, rate=hps.data.sampling_rate, normalize=False))

# %% [markdown]
# ### Voice Conversion

# %%
dataset = TextAudioSpeakerLoader(hps.data.validation_files, hps.data)
collate_fn = TextAudioSpeakerCollate()
loader = DataLoader(dataset, num_workers=8, shuffle=False,
    batch_size=1, pin_memory=True,
    drop_last=True, collate_fn=collate_fn)
data_list = list(loader)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dataset = TextAudioSpeakerLoader(hps.data.validation_files, hps.data)
#       2 collate_fn = TextAudioSpeakerCollate()
#       3 loader = DataLoader(dataset, num_workers=8, shuffle=False,
#       4     batch_size=1, pin_memory=True,
#       5     drop_last=True, collate_fn=collate_fn)
#
# NameError: name 'TextAudioSpeakerLoader' is not defined

# %%
with torch.no_grad():
    x, x_lengths, spec, spec_lengths, y, y_lengths, sid_src = [x.cuda() for x in data_list[0]]
    sid_tgt1 = torch.LongTensor([1]).cuda()
    sid_tgt2 = torch.LongTensor([2]).cuda()
    sid_tgt3 = torch.LongTensor([4]).cuda()
    audio1 = net_g.voice_conversion(spec, spec_lengths, sid_src=sid_src, sid_tgt=sid_tgt1)[0][0,0].data.cpu().float().numpy()
    audio2 = net_g.voice_conversion(spec, spec_lengths, sid_src=sid_src, sid_tgt=sid_tgt2)[0][0,0].data.cpu().float().numpy()
    audio3 = net_g.voice_conversion(spec, spec_lengths, sid_src=sid_src, sid_tgt=sid_tgt3)[0][0,0].data.cpu().float().numpy()
print("Original SID: %d" % sid_src.item())
ipd.display(ipd.Audio(y[0].cpu().numpy(), rate=hps.data.sampling_rate, normalize=False))
print("Converted SID: %d" % sid_tgt1.item())
ipd.display(ipd.Audio(audio1, rate=hps.data.sampling_rate, normalize=False))
print("Converted SID: %d" % sid_tgt2.item())
ipd.display(ipd.Audio(audio2, rate=hps.data.sampling_rate, normalize=False))
print("Converted SID: %d" % sid_tgt3.item())
ipd.display(ipd.Audio(audio3, rate=hps.data.sampling_rate, normalize=False))
